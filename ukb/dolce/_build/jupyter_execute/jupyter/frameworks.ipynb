# %% [markdown]
# You've laid out an elegant and thoughtful neural-fractal structure inspired by Ukubona, with layered epistemic nodes culminating in *M’élève*—the level of transcendence, revelation, or existential synthesis. This final layer is crucial, as it functions not merely as an endpoint but as the reflective domain where the entire system’s meaning (or lack thereof) crystallizes. In your current implementation, the nodes within *M’élève* include terms like **Mortality Rate**, **Organ Failure**, **Hospitalization**, **Dependency**, and **Physical Frailty**. These are powerful and sobering terms, especially within a biomedical or clinical context, but they seem to lock the epistemic arc into a narrow corridor—one that risks missing the broader strategic, cultural, and mythological implications emphasized both in Ukubona and in Steve Blank’s recent synthesis of the US research ecosystem.
#
# Blank’s essay in *Nature* makes a compelling case that the collapse of research infrastructure in the US is not just a financial or technical crisis but an epistemic and civilizational rupture. The dismantling of academic-industry-government synergies, the loss of indirect-cost reimbursement mechanisms, and the erosion of scientific talent are not discrete operational problems—they represent systemic failures that threaten the country’s innovation engine, national security, and mythic self-image as a scientific superpower. Framing these failures as mere inputs to "hospitalization" or "frailty" underrepresents their reach. These aren’t just pathologies of the body—they are signs of a crumbling narrative.

# %% [markdown]
# ```{raw} html
# <style>
# /* Base float frame */
# .float-frame {
#     width: 35%;
#     height: auto;
#     border: 1px solid #ccc;
#     padding: 5px;
#     font-size: 12px;
#     background-color: #f9f9f9;
#     position: relative;
#     text-align: center;
#     margin: 15px;
# }
#
# /* Float direction modifiers */
# .float-left  { float: left;  margin-right: 15px; margin-left: 0; }
# .float-right { float: right; margin-left: 15px; margin-right: 0; }
# .float-center {
#     margin-left: auto;
#     margin-right: auto;
#     float: none;
#     display: block;
# }
#
# /* Responsive fallback */
# @media (max-width: 768px) {
#     .float-left, .float-right, .float-center {
#         float: none;
#         width: 100%;
#         margin: 10px 0;
#     }
# }
#
# /* Image styling */
# .float-frame img {
#     width: 100%;
#     height: auto;
#     display: block;
# }
#
# /* Magnify icon overlay */
# .image-bubble.layered-icon {
#     position: absolute;
#     bottom: 8px;
#     right: 8px;
#     width: 12px;
#     height: 10px;
#     background: none;
#     padding: 0;
#     cursor: pointer;
#     z-index: 5;
# }
#
# .large-icon {
#     position: absolute;
#     width: 100%;
#     height: 100%;
#     background-color: #ddd;
#     border: 1px solid #888;
#     border-radius: 2px;
# }
#
# .small-icon {
#     position: absolute;
#     width: 50%;
#     height: 50%;
#     background-color: #aaa;
#     border: 1px solid #666;
#     border-radius: 2px;
#     bottom: -1px;
#     left: -1px;
# }
#
# .image-bubble.layered-icon:hover .large-icon {
#     background-color: #007BFF;
#     border-color: #0056b3;
# }
#
# .image-bubble.layered-icon:hover .small-icon {
#     background-color: white;
#     border-color: #007BFF;
# }
# </style>

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define the neural network fractal
def define_layers():
    return {
        'Suis': ['Services', 'Agents', 'Principals', 'Risks', 'Data', 'Research', ], # Static
        'Voir': ['Info'],  
        'Choisis': ['Analog', 'Digital'],  
        'Deviens': ['War', 'Start-ups', 'Ventures'],  
        "M'èléve": ['Mythic', 'Exile',  'Vulnerable', 'iStructure', 'Talent']  
    }

# Assign colors to nodes
def assign_colors():
    color_map = { # Dynamic
        'yellow': ['Info'],  
        'paleturquoise': ['Research', 'Digital', 'Ventures', 'Talent'],  
        'lightgreen': ['Data', 'Start-ups', 'Exile', 'iStructure', 'Vulnerable'],  
        'lightsalmon': [
            'Principals', 'Risks', 'Analog',  
            'War', 'Mythic'
        ],
    }
    return {node: color for color, nodes in color_map.items() for node in nodes}

# Calculate positions for nodes
def calculate_positions(layer, x_offset):
    y_positions = np.linspace(-len(layer) / 2, len(layer) / 2, len(layer))
    return [(x_offset, y) for y in y_positions]

# Create and visualize the neural network graph
def visualize_nn():
    layers = define_layers()
    colors = assign_colors()
    G = nx.DiGraph()
    pos = {}
    node_colors = []

    # Add nodes and assign positions
    for i, (layer_name, nodes) in enumerate(layers.items()):
        positions = calculate_positions(nodes, x_offset=i * 2)
        for node, position in zip(nodes, positions):
            G.add_node(node, layer=layer_name)
            pos[node] = position
            node_colors.append(colors.get(node, 'lightgray'))   

    # Add edges (automated for consecutive layers)
    layer_names = list(layers.keys())
    for i in range(len(layer_names) - 1):
        source_layer, target_layer = layer_names[i], layer_names[i + 1]
        for source in layers[source_layer]:
            for target in layers[target_layer]:
                G.add_edge(source, target)

    # Draw the graph
    plt.figure(figsize=(12, 8))
    nx.draw(
        G, pos, with_labels=True, node_color=node_colors, edge_color='gray',
        node_size=3000, font_size=15, connectionstyle="arc3,rad=0.2"
    )
    plt.title("US Research Ecosystem", fontsize=23)    
    # ✅ Save the actual image *after* drawing it
    plt.savefig("../kitabo/ensi/figures/us-research-ecosystem.jpeg", dpi=300, bbox_inches='tight')
    # plt.show()

# Run the visualization
visualize_nn()

# %% [markdown]
# <div class="float-right" style="float:none;width:100%;margin-left:0;border:none;padding:0;background:none;">
#   <a class="image-bubble layered-icon" href="figures/us-research-ecosystem.jpeg" target="_blank" title="Click to magnify">
#     <div class="large-icon"></div>
#     <div class="small-icon"></div>
#   </a>
#
# ```{figure} https://www.ledr.com/colours/white.jpg
# ---
# width: 1
# height: 1
# name: us research ecosystem
# ---
# _Interpretation_. Government agencies risk $200 billion in R&D per year. Start-ups [emerging](https://en.wikipedia.org/wiki/Analog_signal) from this R&D draw in almost dollar-for-dollar venture capital investments. Most technological advancements scale-up the most promising of these efforts into peace-time, war-time, and money-time products and implements.
# ```
#
#   </div>
# </div>
#
# To make the *M’élève* layer resonate more fully with the mythic-symbolic structure of Ukubona and with the themes in Blank’s article, I suggest a reframing. Instead of anchoring this layer in clinical decline, we elevate it into the realm of cultural and strategic disintegration. Suggested new nodes include **Erosion of Talent**, which represents not just a loss of skilled labor but a severing of epistemic lineage and mentorship. It signals the decay of mythic memory across generations. **Infrastructure Decay** captures the symbolic rot of institutions—what happens when once-glorious edifices, physical or symbolic, fall into entropy due to neglect. It’s the quiet, grinding death of the possible.
#
# **Strategic Vulnerability** enters as a node that synthesizes multiple lower-level risks—economic, geopolitical, and cognitive—into a condition of exposed fragility. It is not a singular failure but an emergent property of systemic breakdown. Next, **Cognitive Exile** addresses the dislocation of scientists, thinkers, and creators from viable cognitive habitats. This is more than brain drain—it is the feeling of being exiled from relevance, of having no place in the narrative, of becoming mythically homeless. Finally, **Mythic Discontinuity** is perhaps the most Ukubonic of all. It marks the moment when the narrative thread snaps, when cultures, systems, and civilizations can no longer stitch a meaningful story from their parts. It is what happens when The Dude’s rug is not just stolen but incinerated—when nothing remains to tie the room together.
#
# If desired, these can be augmented by optional additions like **Symbolic Drought**, which denotes a system’s inability to generate new metaphors or meanings, **Echo-State Collapse**, a nod to neural networks that lose dynamic memory and become inert, and **Future Shock**, in the Tofflerian sense of a system overwhelmed by the pace of its own evolution. Visually, these nodes can be emphasized in your `matplotlib` graph using subtle glow effects or translucent overlays to suggest their transcendental or terminal quality.
#
# In sum, by reframing *M’élève* to encapsulate mythic, systemic, and strategic collapse—not just clinical frailty—you align the network’s final layer with the philosophical, cultural, and narrative ambitions of Ukubona. This shift not only makes your visualization more meaningful but also more faithful to the symbolic stakes of our current moment. Let me know if you’d like this translated directly into the updated code with styling hints.
